# %% [markdown]
# <a href="https://colab.research.google.com/github/shivanshu-mishra01/ML-Projects-/blob/main/Placement%20Predictor%20model%20using%20ML_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/placement.csv")
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["cgpa"],df["iq"],c=df["placement"])

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x.head()
# Out:
#    cgpa     iq
# 0   6.8  123.0
# 1   5.9  106.0
# 2   5.3  121.0
# 3   7.4  132.0
# 4   5.8  142.0

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: placement, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 20   6.6  120.0
# 31   3.9  109.0
# 98   6.3  103.0
# 11   6.9  138.0
# 8    6.1  156.0
# ..   ...    ...
# 79   6.5   90.0
# 6    5.7  143.0
# 46   5.3  114.0
# 95   4.3  200.0
# 78   6.1   81.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 20    1
# 31    0
# 98    1
# 11    1
# 8     0
#      ..
# 79    1
# 6     0
# 46    0
# 95    0
# 78    0
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 14   6.1  103.0
# 93   6.8  112.0
# 26   7.0  199.0
# 18   4.0  100.0
# 32   7.0  139.0
# 59   4.8  112.0
# 36   5.7  140.0
# 76   4.9  155.0
# 62   6.0  102.0
# 40   4.9  134.0

# %%
y_test
# Out:
# 14    0
# 93    1
# 26    1
# 18    0
# 32    1
# 59    0
# 36    0
# 76    0
# 62    0
# 40    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)
x_train
# Out:
# array([[ 5.03752342e-01, -7.15670818e-02],
#        [-1.84580273e+00, -3.41992315e-01],
#        [ 2.42690668e-01, -4.89496987e-01],
#        [ 7.64814017e-01,  3.70946935e-01],
#        [ 6.86495515e-02,  8.13460953e-01],
#        [ 1.80906072e+00,  6.41372168e-01],
#        [-1.06261770e+00,  9.85549737e-01],
#        [-1.83710067e-02, -1.39910913e+00],
#        [-1.14963826e+00, -1.74328670e+00],
#        [-2.79432681e-01,  1.13305441e+00],
#        [-8.88576589e-01, -7.84506332e-01],
#        [-1.83710067e-02,  2.67693665e-02],
#        [-2.79432681e-01,  2.23442263e-01],
#        [-1.75878217e+00, -1.17785212e+00],
#        [ 1.55670110e-01, -2.43655866e-01],
#        [ 5.90772901e-01,  7.64292728e-01],
#        [-1.83710067e-02, -1.91537549e+00],
#        [ 1.28693737e+00,  1.74274039e-01],
#        [ 6.86495515e-02, -1.42369325e+00],
#        [ 1.11289625e+00, -1.69903530e-01],
#        [ 2.42690668e-01,  1.25105815e-01],
#        [-9.75597147e-01, -1.52202969e+00],
# ...

# %%
x_test=sc.transform(x_test)
x_test
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# array([[  6.1, 103. ],
#        [  6.8, 112. ],
#        [  7. , 199. ],
#        [  4. , 100. ],
#        [  7. , 139. ],
#        [  4.8, 112. ],
#        [  5.7, 140. ],
#        [  4.9, 155. ],
#        [  6. , 102. ],
#        [  4.9, 134. ]])

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()

# %%
# model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#evaluating model
y_pred=model.predict(x_test)

# %%
y_test
# Out:
# 14    0
# 93    1
# 26    1
# 18    0
# 32    1
# 59    0
# 36    0
# 76    0
# 62    0
# 40    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.4

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle  # it coverts all objcts into file so
# can be used anywhere

# %%
pickle.dump(clf,open("model.pkl","wb"))
